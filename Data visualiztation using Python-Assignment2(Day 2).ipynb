# %% [markdown]
# L Siva Priya
# Question 1
# Create a dataframe with 10 rows on random numbers and 4 columns, (columns labelled as a,b,c,d) and plot a bar chart.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline
from numpy.random import randn,randint,uniform,sample

# %%
df = pd.DataFrame(randn(10,4),columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.185479 -1.337834  0.209905 -0.377778
# 1 -0.192724 -0.532856  0.547057  0.025790
# 2 -0.512883 -0.629490 -0.383699  2.071408
# 3  0.900555  0.317550 -0.031221 -1.139097
# 4  1.177981  1.606189 -1.542461  0.420275
# 5  0.261149 -0.253331 -0.040328 -1.478249
# 6 -0.410486  0.541438  0.813234  0.708201
# 7 -2.128353  0.297430  0.951201 -2.033575
# 8 -0.867234  0.794347 -1.126402 -0.625522
# 9  1.131663 -0.024460 -0.106700  0.265032

# %%
df.plot(kind='bar',title='Bar Chart',figsize=(16,18),grid=True,legend = True)
plt.show()
